# %%
# Import all necessary libraries.
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# %%
# Create training dataset
x = np.array([[1, 4], [4, 3], [4, 5], [3, 6], [6, 7], [3, 3], [2, 5], [2, 2], [2, 3]])

# %% [markdown]
# ## Show Training data set

# %%
# Data Ploting
fig = plt.figure(figsize=(10,10))
plt.scatter(x[:, 0], x[:,1], s = 100, color = 'blue', label = 'Data Training')
plt.xlabel('$x_1$', fontsize=14)
plt.ylabel('$x_2$', fontsize=14)
plt.legend(loc="lower right")
plt.grid()
#plt.savefig('Data_plot.png', dpi=600)
plt.show()

# %% [markdown]
# ## KMeans instance

# %%
# Initial Centroids
init_clusters = np.array([[5, 3], [1, 3], [3, 4]])

# Create an instance of KMeans Cluster 
km = KMeans(n_clusters=3, init=init_clusters)

# %% [markdown]
# ## Training Model and print great values

# %%
# Training
km.fit(x)

# Great Centroids
for i in range(0, 3):
    print('Centroid %d: (%1.2f, %1.2f)' % (i, km.cluster_centers_[i][0], km.cluster_centers_[i][1]))
# Out:
# Centroid 0: (6.00, 7.00)
# Centroid 1: (2.00, 3.00)
# Centroid 2: (3.25, 4.75)
# C:\Users\mferrero\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: RuntimeWarning: Explicit initial center position passed: performing only one init in k-means instead of n_init=10

# %% [markdown]
# ## Iterations to training of model

# %%
# Number of iterations required to train the model
print('Number of Iterations:', km.n_iter_)
# Out:
# Number of Iterations: 4

# %% [markdown]
# ## Show Training data - Cluster and Centroid

# %%
# Figura com os resultados
fig = plt.figure(figsize=(10,10))
plt.scatter(x[:,0], x[:,1], s = 150, c = km.labels_)
plt.scatter(km.cluster_centers_[:, 0], km.cluster_centers_[:, 1], s = 300, c = 'green', label = 'Centroids')
plt.title('Training data with Clusters and Centroids')
plt.xlabel('$x_1$', fontsize=14)
plt.ylabel('$x_2$', fontsize=14)
plt.legend(loc="lower right")
plt.grid()
#plt.savefig('Data_separated_by_clusters.png', dpi=600)
plt.show()
